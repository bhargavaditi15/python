# %% [markdown]
# # Read CSV

# %%
import pandas as pd

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv")

csv_1
# Out:
#        Type         Component  2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# 0    Income            Salary    60000.00    60000.00    60000.00    60000.00
# 1    Income        Freelancig     1000.00     1000.00     2000.00     3000.00
# 2   Savings      Mutual funds     6000.00     6000.00     6000.00     6000.00
# 3   Savings    Emergency Fund     2000.00     2000.00     2000.00     2000.00
# 4   Savings     Fixed Deposit     2000.00     2000.00     2000.00     2000.00
# 5   Savings       Liquid Cash    35600.00    34600.00    36600.00    36600.00
# 6   Expense        House Rent    10000.00    10000.00    10000.00    10000.00
# 7   Expense  Groceries & Food     6000.00     6000.00     6000.00     6000.00
# 8   Expense            Health     1000.00     1000.00     1000.00     1000.00
# 9   Expense              EMIs     2600.00     2600.00     2600.00     2600.00
# 10  Expense           Leisure      600.00     1600.00      600.00     1600.00
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",nrows=1)

csv_1
# Out:
#      Type Component  2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# 0  Income    Salary       60000       60000       60000       60000
#
#    2021-05-01  2021-06-01  2021-07-01  2021-08-01  ...  2023-05-01  \
# 0       60000       60000       60000       60000  ...       75000
#
#    2023-06-01  2023-07-01  2023-08-01  2023-09-01  2023-10-01  2023-11-01  \
# 0       75000       75000       75000       75000       75000       75600
#
#    2023-12-01  2024-01-01  2024-02-01
# 0       75600       75600       75600
#
# [1 rows x 40 columns]

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv")

print(type(csv_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",nrows=5)

csv_1
# Out:
#       Type       Component  2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# 0   Income          Salary       60000       60000       60000       60000
# 1   Income      Freelancig        1000        1000        2000        3000
# 2  Savings    Mutual funds        6000        6000        6000        6000
# 3  Savings  Emergency Fund        2000        2000        2000        2000
# 4  Savings   Fixed Deposit        2000        2000        2000        2000
#
#    2021-05-01  2021-06-01  2021-07-01  2021-08-01  ...  2023-05-01  \
# 0       60000       60000       60000       60000  ...       75000
# 1        3000        2000        2000        1000  ...        4000
# 2        6000        6000        6000        6000  ...        7000
# 3        2000        2000        2000           0  ...        2000
# 4        2000        2000        2000        2000  ...           0
#
#    2023-06-01  2023-07-01  2023-08-01  2023-09-01  2023-10-01  2023-11-01  \
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",usecols=["Component","2021-01-01"])

csv_1
# Out:
#            Component  2021-01-01
# 0             Salary    60000.00
# 1         Freelancig     1000.00
# 2       Mutual funds     6000.00
# 3     Emergency Fund     2000.00
# 4      Fixed Deposit     2000.00
# 5        Liquid Cash    35600.00
# 6         House Rent    10000.00
# 7   Groceries & Food     6000.00
# 8             Health     1000.00
# 9               EMIs     2600.00
# 10           Leisure      600.00
# 11          Shopping     1000.00
# 12            Trevel      200.00
# 13             Other      100.00
# 14           Savings        0.25

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",usecols=[0,3])

csv_1
# Out:
#        Type  2021-02-01
# 0    Income    60000.00
# 1    Income     1000.00
# 2   Savings     6000.00
# 3   Savings     2000.00
# 4   Savings     2000.00
# 5   Savings    34600.00
# 6   Expense    10000.00
# 7   Expense     6000.00
# 8   Expense     1000.00
# 9   Expense     2600.00
# 10  Expense     1600.00
# 11  Expense     1000.00
# 12  Expense      200.00
# 13  Expense      300.00
# 14   Target        0.25

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",skiprows=[0])

csv_1
# Out:
#      Income            Salary     60000   60000.1   60000.2   60000.3  \
# 0    Income        Freelancig   1000.00   1000.00   2000.00   3000.00
# 1   Savings      Mutual funds   6000.00   6000.00   6000.00   6000.00
# 2   Savings    Emergency Fund   2000.00   2000.00   2000.00   2000.00
# 3   Savings     Fixed Deposit   2000.00   2000.00   2000.00   2000.00
# 4   Savings       Liquid Cash  35600.00  34600.00  36600.00  36600.00
# 5   Expense        House Rent  10000.00  10000.00  10000.00  10000.00
# 6   Expense  Groceries & Food   6000.00   6000.00   6000.00   6000.00
# 7   Expense            Health   1000.00   1000.00   1000.00   1000.00
# 8   Expense              EMIs   2600.00   2600.00   2600.00   2600.00
# 9   Expense           Leisure    600.00   1600.00    600.00   1600.00
# 10  Expense          Shopping   1000.00   1000.00   1000.00   1000.00
# 11  Expense            Trevel    200.00    200.00    200.00    200.00
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",skiprows=[0,3,5,6])

csv_1
# Out:
#      Income            Salary     60000   60000.1   60000.2   60000.3  \
# 0    Income        Freelancig   1000.00   1000.00   2000.00   3000.00
# 1   Savings    Emergency Fund   2000.00   2000.00   2000.00   2000.00
# 2   Expense        House Rent  10000.00  10000.00  10000.00  10000.00
# 3   Expense  Groceries & Food   6000.00   6000.00   6000.00   6000.00
# 4   Expense            Health   1000.00   1000.00   1000.00   1000.00
# 5   Expense              EMIs   2600.00   2600.00   2600.00   2600.00
# 6   Expense           Leisure    600.00   1600.00    600.00   1600.00
# 7   Expense          Shopping   1000.00   1000.00   1000.00   1000.00
# 8   Expense            Trevel    200.00    200.00    200.00    200.00
# 9   Expense             Other    100.00    300.00    500.00    300.00
# 10   Target           Savings      0.25      0.25      0.25      0.25
#
#      60000.4   60000.5   60000.6   60000.7  ...  75000.4  75000.5  75000.6  \
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",index_col="Type")

csv_1
# Out:
#                 Component  2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# Type
# Income             Salary    60000.00    60000.00    60000.00    60000.00
# Income         Freelancig     1000.00     1000.00     2000.00     3000.00
# Savings      Mutual funds     6000.00     6000.00     6000.00     6000.00
# Savings    Emergency Fund     2000.00     2000.00     2000.00     2000.00
# Savings     Fixed Deposit     2000.00     2000.00     2000.00     2000.00
# Savings       Liquid Cash    35600.00    34600.00    36600.00    36600.00
# Expense        House Rent    10000.00    10000.00    10000.00    10000.00
# Expense  Groceries & Food     6000.00     6000.00     6000.00     6000.00
# Expense            Health     1000.00     1000.00     1000.00     1000.00
# Expense              EMIs     2600.00     2600.00     2600.00     2600.00
# Expense           Leisure      600.00     1600.00      600.00     1600.00
# Expense          Shopping     1000.00     1000.00     1000.00     1000.00
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",header = 2)

csv_1
# Out:
#      Income        Freelancig      1000    1000.1      2000      3000  \
# 0   Savings      Mutual funds   6000.00   6000.00   6000.00   6000.00
# 1   Savings    Emergency Fund   2000.00   2000.00   2000.00   2000.00
# 2   Savings     Fixed Deposit   2000.00   2000.00   2000.00   2000.00
# 3   Savings       Liquid Cash  35600.00  34600.00  36600.00  36600.00
# 4   Expense        House Rent  10000.00  10000.00  10000.00  10000.00
# 5   Expense  Groceries & Food   6000.00   6000.00   6000.00   6000.00
# 6   Expense            Health   1000.00   1000.00   1000.00   1000.00
# 7   Expense              EMIs   2600.00   2600.00   2600.00   2600.00
# 8   Expense           Leisure    600.00   1600.00    600.00   1600.00
# 9   Expense          Shopping   1000.00   1000.00   1000.00   1000.00
# 10  Expense            Trevel    200.00    200.00    200.00    200.00
# 11  Expense             Other    100.00    300.00    500.00    300.00
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",names=["col"])

csv_1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         col
# Type    Component        2021-01-01 2021-02-01 2021-03-01 2021-04-01 2021-05-01 2021-06-01 2021-07-01 2021-08-01 2021-09-01 2021-10-01 2021-11-01 2021-12-01 2022-01-01 2022-02-01 2022-03-01 2022-04-01 2022-05-01 2022-06-01 2022-07-01 2022-08-01 2022-09-01 2022-10-01 2022-11-01 2022-12-01 2023-01-01 2023-02-01 2023-03-01 2023-04-01 2023-05-01 2023-06-01 2023-07-01 2023-08-01 2023-09-01 2023-10-01 2023-11-01 2023-12-01 2024-01-01  2024-02-01
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv",names=["col1","col2","col3","col4","col5"])

csv_1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                            col1  \
# Type    Component        2021-01-01 2021-02-01 2021-03-01 2021-04-01 2021-05-01 2021-06-01 2021-07-01 2021-08-01 2021-09-01 2021-10-01 2021-11-01 2021-12-01 2022-01-01 2022-02-01 2022-03-01 2022-04-01 2022-05-01 2022-06-01 2022-07-01 2022-08-01 2022-09-01 2022-10-01 2022-11-01 2022-12-01 2023-01-01 2023-02-01 2023-03-01 2023-04-01 2023-05-01 2023-06-01 2023-07-01 2023-08-01 2023-09-01  2023-10-01
# ...

# %%
csv_1 = pd.read_csv("C:\\Users\\aditi\\python\\pandas\\Finance Dataset.csv", dtype={"2021-01-01":"float"})

csv_1
# Out:
#        Type         Component  2021-01-01  2021-02-01  2021-03-01  2021-04-01  \
# 0    Income            Salary    60000.00    60000.00    60000.00    60000.00
# 1    Income        Freelancig     1000.00     1000.00     2000.00     3000.00
# 2   Savings      Mutual funds     6000.00     6000.00     6000.00     6000.00
# 3   Savings    Emergency Fund     2000.00     2000.00     2000.00     2000.00
# 4   Savings     Fixed Deposit     2000.00     2000.00     2000.00     2000.00
# 5   Savings       Liquid Cash    35600.00    34600.00    36600.00    36600.00
# 6   Expense        House Rent    10000.00    10000.00    10000.00    10000.00
# 7   Expense  Groceries & Food     6000.00     6000.00     6000.00     6000.00
# 8   Expense            Health     1000.00     1000.00     1000.00     1000.00
# 9   Expense              EMIs     2600.00     2600.00     2600.00     2600.00
# 10  Expense           Leisure      600.00     1600.00      600.00     1600.00
# ...
